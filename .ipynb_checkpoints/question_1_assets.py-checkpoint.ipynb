# %%
import pandas as pd
import os
import sys

# Add the parent directory to Python's search path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# Ensure correct import path (if running inside Jupyter)
from scripts.load_data import load_data  # Ensure lowercase 'scripts'

# %%
# Define the Excel file path
file_path = "data/Common Data Warehouse-Orginal.xlsx"

# Load merged dataset
final_df = load_data(file_path)

# Display first few rows
final_df.head()
# Out:
#          Agmt ID     GL Acct ID   Source        Cust ID   Amount  \
# 0  1000162418540  1000000008710  229|ADJ  1000007793706     0.00
# 1  1000376865946  1000000013691      229  1000009653088 -5198.52
# 2  1000205191664  1000000008710  229|ADJ  1000044609208     0.00
# 3  1000329416423  1000000008710  229|ADJ  1000009657652     0.00
# 4  1000239743539  1000000008710  229|ADJ  1000007699415     0.00
#
#      Customer ID Local Customer ID                  Customer Name  \
# 0  1000007793706         990597391  HWTYLL LYXLXGHYTYR HWLDXNG ZS
# 1  1000009653088        4216007625                            NaN
# 2  1000044609208         997510461     FWRQS MZRKYRXNG HWLDXNG ZS
# 3  1000009657652        4333246983            STYNHØJ HWLDXNG Z/S
# 4  1000007699415         936370446                       SYRVX ZS
#
#   NACE Code L1                                       NACE Name L1  ...  \
# 0            L                             REAL ESTATE ACTIVITIES  ...
# 1            A                  AGRICULTURE, FORESTRY AND FISHING  ...
# 2            K                 FINANCIAL AND INSURANCE ACTIVITIES  ...
# 3            M  PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES  ...
# 4            G                         WHOLESALE AND RETAIL TRADE  ...
#
#           Amortization Method  GL Account ID GL Account  \
# 0                         NaN  1000000008710     100400
# 1  IRREGULAR (CURRENCY LOANS)  1000000013691     104413
# 2  AMORTIZATION FREE (BULLET)  1000000008710     100400
# 3  IRREGULAR (CURRENCY LOANS)  1000000008710     100400
# 4  AMORTIZATION FREE (BULLET)  1000000008710     100400
#
#                                         GL Name  Group GL Acct ID  \
# 0                       Loans non-demand, other     1000000002728
# 1  Accrued interest income - Loans, L&R - delta     1000000103203
# 2                       Loans non-demand, other     1000000002728
# 3                       Loans non-demand, other     1000000002728
# 4                       Loans non-demand, other     1000000002728
#
#    GL Account Type GL Account Name  Group GL Account ID  Group GL Account  \
# 0                1          Assets        1000000002728           G100400
# 1                1          Assets        1000000103203           G100601
# 2                1          Assets        1000000002728           G100400
# 3                1          Assets        1000000002728           G100400
# 4                1          Assets        1000000002728           G100400
#
#                  Group GL Name
# 0         Loans non-demand, AC
# 1  Accrued interest income, AC
# 2         Loans non-demand, AC
# 3         Loans non-demand, AC
# 4         Loans non-demand, AC
#
# [5 rows x 39 columns]

# %%
# Separate Total Assets and Off-Balance Items
total_assets_df = final_df[final_df["Group GL Name"] != "Off Balance"].groupby("Sector Name").agg(
    Total_Assets=("Amount", "sum")
).reset_index()

off_balance_df = final_df[final_df["Group GL Name"] == "Off Balance"].groupby("Sector Name").agg(
    Off_Balance_Amount=("Amount", "sum"),
    Off_Balance_Count=("Group GL Name", "count")
).reset_index()

# Merge results
sector_analysis = total_assets_df.merge(
    off_balance_df, on="Sector Name", how="left"
).fillna(0)

# Display Results
sector_analysis
# Out:
#                     Sector Name  Total_Assets  Off_Balance_Amount  \
# 0                 Central Banks -4.577565e+05        0.000000e+00
# 1           Credit institutions -4.278055e+09       -6.201119e+10
# 2           General governments -1.003070e+09       -8.674180e+08
# 3                    Households -4.138537e+08       -1.151603e+07
# 4    Non financial corporations -4.115274e+10       -2.233238e+10
# 5  Other financial corporations -3.107687e+09       -1.427112e+09
#
#    Off_Balance_Count
# 0                0.0
# 1               11.0
# 2               30.0
# 3                7.0
# 4             1100.0
# 5               54.0

# %%
# Save results to Excel
sector_analysis.to_excel("data/Sector_Analysis.xlsx", index=False)
print("Sector Assets Analysis saved to data/Sector_Analysis.xlsx")
# Out:
# Sector Assets Analysis saved to data/Sector_Analysis.xlsx

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot Total Assets by Sector
plt.figure(figsize=(12, 6))
sns.barplot(x="Total_Assets", y="Sector Name", data=sector_analysis, palette="Blues_r")
plt.xlabel("Total Assets ($)")
plt.ylabel("Customer Sector")
plt.title("Total Assets per Customer Sector")
plt.show()

# Plot Off-Balance Amount by Sector
plt.figure(figsize=(12, 6))
sns.barplot(x="Off_Balance_Amount", y="Sector Name", data=sector_analysis, palette="Reds_r")
plt.xlabel("Off-Balance Sheet Amount ($)")
plt.ylabel("Customer Sector")
plt.title("Off-Balance Sheet Amount per Customer Sector")
plt.show()
